# %% [markdown]
# <a href="https://colab.research.google.com/github/pritam17/MyProject1/blob/master/3_Text_Classification_with_Keras_amazon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from nltk import word_tokenize
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from tensorflow.keras.models import Model
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# !wget https://www.dropbox.com/sh/edjj4duz16m6fdj/AACh0xl7wTz3GHNMBV3P6hTpa/sentiment%20labelled%20sentences/imdb_labelled.txt?dl=0 /content/drive
# Out:
# --2020-01-11 11:07:57--  https://www.dropbox.com/sh/edjj4duz16m6fdj/AACh0xl7wTz3GHNMBV3P6hTpa/sentiment%20labelled%20sentences/imdb_labelled.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/edjj4duz16m6fdj/AACh0xl7wTz3GHNMBV3P6hTpa/sentiment%20labelled%20sentences/imdb_labelled.txt [following]
# --2020-01-11 11:07:57--  https://www.dropbox.com/sh/raw/edjj4duz16m6fdj/AACh0xl7wTz3GHNMBV3P6hTpa/sentiment%20labelled%20sentences/imdb_labelled.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf182df7eda6f29d65d74e99791.dl.dropboxusercontent.com/cd/0/inline/Av_RcRT09jqa_BzhNQr7A-oxp42tYASTIB06pFwKgBp7OG9xY09JyomLxda5s5XfsJFEfHl7KARA7F2Bwowgushr1pOhcbGqGyPKZT26-FcTCw/file# [following]
# --2020-01-11 11:07:58--  https://ucf182df7eda6f29d65d74e99791.dl.dropboxusercontent.com/cd/0/inline/Av_RcRT09jqa_BzhNQr7A-oxp42tYASTIB06pFwKgBp7OG9xY09JyomLxda5s5XfsJFEfHl7KARA7F2Bwowgushr1pOhcbGqGyPKZT26-FcTCw/file
# Resolving ucf182df7eda6f29d65d74e99791.dl.dropboxusercontent.com (ucf182df7eda6f29d65d74e99791.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601b:6::a27d:806
# Connecting to ucf182df7eda6f29d65d74e99791.dl.dropboxusercontent.com (ucf182df7eda6f29d65d74e99791.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85279 (83K) [text/plain]
# Saving to: ‘imdb_labelled.txt?dl=0’
#
# imdb_labelled.txt?d 100%[===================>]  83.28K  --.-KB/s    in 0.05s
#
# 2020-01-11 11:07:58 (1.73 MB/s) - ‘imdb_labelled.txt?dl=0’ saved [85279/85279]
#
# /content/drive: Scheme missing.
# FINISHED --2020-01-11 11:07:58--
# Total wall clock time: 0.9s
# Downloaded: 1 files, 83K in 0.05s (1.73 MB/s)

# %%
file=r'/content/imdb_labelled.txt?dl=0'

# %%
imdb=pd.read_csv(file,sep='\t',header=None,names=['review','sentiment'])

# %%
import re
import nltk
nltk.download('punkt')
imdb["length"]=imdb.review.apply(lambda x:len(x.split()))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
imdb.length.value_counts()
# Out:
# 11      48
# 12      42
# 5       41
# 8       40
# 7       38
# 9       36
# 16      32
# 10      32
# 6       32
# 15      31
# 20      29
# 4       27
# 14      26
# 19      25
# 3       23
# 13      23
# 21      21
# 17      17
# 23      16
# 24      15
# 18      15
# 22      13
# 2       12
# 25      11
# 31      10
# 34      10
# 33       8
# 26       7
# 28       7
# 30       6
# 27       6
# 1        5
# 32       5
# 29       5
# 35       4
# 38       4
# 45       3
# 36       3
# 40       2
# 43       2
# 47       2
# 56       1
# 1390     1
# 302      1
# 199      1
# 71       1
# 62       1
# 797      1
# 54       1
# 53       1
# 51       1
# 42       1
# 39       1
# 37       1
# 865      1
# Name: length, dtype: int64

# %%
imdb_train,imdb_test=train_test_split(imdb,test_size=0.2,random_state=2)

# %%
x_train=imdb_train['review']
y_train=imdb_train['sentiment']
x_test=imdb_test['review']
y_test=imdb_test['sentiment']

# %%
sent_lens=[]
for sent in imdb_train['review']:
    sent_lens.append(len(word_tokenize(sent)))

# %%
max(sent_lens)
# Out:
# 1616

# %%
# sent_lens

# %%
np.quantile(sent_lens,0.99)
# Out:
# 62.3299999999997

# %%
# We can see that 95% review text are of lengths less than or equal to 37. We'll keep the max length to 30

# %%
max_len = 63

tok = Tokenizer(char_level=False,split=' ')

tok.fit_on_texts(x_train)

# %%
tok.index_word
# Out:
# {1: 'the',
#  2: 'a',
#  3: 'and',
#  4: 'of',
#  5: 'is',
#  6: 'this',
#  7: 'it',
#  8: 'i',
#  9: 'to',
#  10: 'was',
#  11: 'movie',
#  12: 'in',
#  13: 'film',
#  14: 'that',
#  15: '1',
#  16: '0',
#  17: 'but',
#  18: 'for',
#  19: 'as',
#  20: 'with',
#  21: 'are',
#  22: 'on',
#  23: 'not',
#  24: 'you',
#  25: 'one',
#  26: 'very',
#  27: 'bad',
#  28: 'just',
#  29: 'so',
#  30: 'good',
#  31: 'all',
#  32: 'an',
#  33: "it's",
#  34: 'there',
#  35: 'be',
#  36: 'by',
#  37: 'about',
#  38: 'at',
#  39: 'if',
#  40: 'out',
#  41: 'great',
#  42: 'his',
#  43: 'from',
#  44: 'like',
#  45: 'have',
#  46: 'time',
#  47: 'were',
#  48: 'well',
#  49: 'has',
#  50: 'even',
#  51: 'really',
#  52: 'my',
#  53: 'or',
#  54: 'who',
#  55: 'acting',
#  56: 'he',
#  57: 'when',
#  58: 'most',
#  59: 'see',
#  60: 'how',
#  61: 'more',
#  62: 'characters',
#  63: 'would',
#  64: 'no',
#  65: 'only',
#  66: 'ever',
#  67: 'made',
#  68: 'also',
#  69: 'best',
#  70: '10',
#  71: 'plot',
#  72: 'some',
#  73: 'your',
#  74: 'do',
#  75: 'its',
#  76: 'character',
#  77: 'real',
#  78: 'because',
#  79: 'love',
#  80: "didn't",
#  81: 'movies',
#  82: 'can',
#  83: "don't",
#  84: 'other',
#  85: 'which',
#  86: 'they',
#  87: 'story',
#  88: 'way',
#  89: 'films',
#  90: 'actors',
#  91: 'think',
#  92: 'much',
#  93: 'seen',
#  94: 'too',
#  95: 'her',
#  96: 'me',
#  97: 'every',
#  98: 'script',
#  99: 'watching',
#  100: 'than',
#  101: 'had',
#  102: 'up',
#  103: 'scenes',
#  104: 'over',
#  105: 'wonderful',
#  106: 'show',
#  107: 'what',
#  108: 'could',
#  109: 'little',
#  110: 'watch',
#  111: 'will',
#  112: 'funny',
#  113: 'work',
#  114: 'any',
#  115: 'worth',
#  116: 'make',
#  117: 'here',
#  118: 'man',
#  119: 'art',
#  120: 'music',
#  121: 'into',
#  122: 'cast',
#  123: 'many',
#  124: 'better',
#  125: 'screen',
#  126: 'totally',
#  127: 'go',
#  128: 'both',
#  129: 'their',
#  130: 'never',
#  131: 'anyone',
#  132: 'say',
#  133: 'look',
#  134: 'nothing',
#  135: 'everything',
#  136: 'after',
#  137: 'again',
#  138: 'thought',
#  139: 'line',
#  140: 'waste',
#  141: 'get',
#  142: 'life',
#  143: 'excellent',
#  144: 'dialogue',
#  145: 'scene',
#  146: 'still',
#  147: 'such',
#  148: 'being',
#  149: "doesn't",
#  150: 'writing',
#  151: 'people',
#  152: 'performance',
#  153: 'going',
#  154: 'awful',
#  155: 'things',
#  156: 'years',
#  157: 'right',
#  158: 'recommend',
#  159: 'know',
#  160: 'director',
#  161: "i'm",
#  162: 'truly',
#  163: 'off',
#  164: 'she',
#  165: 'cinematography',
#  166: 'saw',
#  167: 'enough',
#  168: 'been',
#  169: 'stupid',
#  170: 'them',
#  171: 'liked',
#  172: 'however',
#  173: 'though',
#  174: 'simply',
#  175: 'give',
#  176: 'ending',
#  177: 'thing',
#  178: 'feeling',
#  179: 'enjoyed',
#  180: 'beautiful',
#  181: "i've",
#  182: 'terrible',
#  183: "can't",
#  184: 'should',
#  185: 'am',
#  186: 'actually',
#  187: 'lot',
#  188: 'makes',
#  189: 'through',
#  190: 'does',
#  191: 'game',
#  192: 'camera',
#  193: 'worst',
#  194: 'predictable',
#  195: 'whole',
#  196: 'done',
#  197: "that's",
#  198: 'definitely',
#  199: 'loved',
#  200: 'job',
#  201: 'part',
#  202: 'pretty',
#  203: 'quite',
#  204: 'drama',
#  205: 'highly',
#  206: 'black',
#  207: 'between',
#  208: 'found',
#  209: 'play',
#  210: 'two',
#  211: 'understand',
#  212: 'these',
#  213: 'kind',
#  214: 'first',
#  215: 'interesting',
#  216: 'those',
#  217: 'find',
#  218: 'another',
#  219: 'series',
#  220: 'kids',
#  221: 'we',
#  222: 'written',
#  223: 'did',
#  224: 'worse',
#  225: 'played',
#  226: 'watched',
#  227: 'least',
#  228: 'sucked',
#  229: 'old',
#  230: 'actor',
#  231: 'playing',
#  232: 'horror',
#  233: 'seeing',
#  234: 'got',
#  235: 'wasted',
#  236: 'big',
#  237: 'mostly',
#  238: 'believe',
#  239: 'incredible',
#  240: 'whatever',
#  241: 'directing',
#  242: 'casting',
#  243: 'where',
#  244: 'hilarious',
#  245: 'anything',
#  246: 'top',
#  247: 'self',
#  248: 'cool',
#  249: 'gives',
#  250: 'gets',
#  251: 'classic',
#  252: 'money',
#  253: 'cheap',
#  254: 'now',
#  255: 'piece',
#  256: 'absolutely',
#  257: 'tv',
#  258: 'rent',
#  259: 'use',
#  260: 'suspense',
#  261: 'lacks',
#  262: 'lines',
#  263: 'action',
#  264: 'then',
#  265: "wasn't",
#  266: 'short',
#  267: 'together',
#  268: 'boring',
#  269: 'white',
#  270: 'disappointed',
#  271: 'having',
#  272: 'style',
#  273: 'myself',
#  274: 'oh',
#  275: 'pathetic',
#  276: 'long',
#  277: 'come',
#  278: 'want',
#  279: 'probably',
#  280: 'each',
#  281: 'john',
#  282: 'fine',
#  283: 'memorable',
#  284: 'avoid',
#  285: 'face',
#  286: 'superb',
#  287: 'cinema',
#  288: 'yet',
#  289: 'year',
#  290: 'joy',
#  291: 'sound',
#  292: 'comedy',
#  293: 'special',
#  294: 'effects',
#  295: 'experience',
#  296: 'recommended',
#  297: 'throughout',
#  298: 'minutes',
#  299: 'clever',
#  300: 'end',
#  301: 'period',
#  302: 'particularly',
#  303: 'tom',
#  304: 'take',
#  305: 'terrific',
#  306: 'second',
#  307: 'him',
#  308: 'fact',
#  309: 'new',
#  310: 'talk',
#  311: 'poor',
#  312: 'flick',
#  313: 'used',
#  314: 'enjoy',
#  315: 'said',
#  316: "i'd",
#  317: 'amazing',
#  318: 'history',
#  319: 'shot',
#  320: 'ridiculous',
#  321: 'far',
#  322: 'entire',
#  323: 'slow',
#  324: 'rather',
#  325: 'different',
#  326: 'few',
#  327: 'works',
#  328: 'almost',
#  329: 'budget',
#  330: 'own',
#  331: 'half',
#  332: 'editing',
#  333: 'especially',
#  334: 'certainly',
#  335: 'storyline',
#  336: 'single',
#  337: 'soundtrack',
#  338: 'times',
#  339: 'sometimes',
#  340: 'girl',
#  341: 'production',
#  342: 'human',
#  343: "there's",
#  344: 'why',
#  345: 'put',
#  346: 'lead',
#  347: 'mess',
#  348: 'place',
#  349: 'mention',
#  350: 'gave',
#  351: 'adorable',
#  352: 'without',
#  353: 'solid',
#  354: 'point',
#  355: 'hope',
#  356: 'us',
#  357: 'nice',
#  358: 'energy',
#  359: 'small',
#  360: 'become',
#  361: 'care',
#  362: 'annoying',
#  363: 'mean',
#  364: 'completely',
#  365: 'insult',
#  366: 'theater',
#  367: 'fails',
#  368: 'making',
#  369: 'indeed',
#  370: 'word',
#  371: 'cult',
#  372: 'let',
#  373: 'before',
#  374: 'everyone',
#  375: 'amount',
#  376: 'something',
#  377: 'huge',
#  378: 'pretentious',
#  379: 'during',
#  380: 'hard',
#  381: 'ray',
#  382: 'hitchcock',
#  383: 'audience',
#  384: 'extremely',
#  385: 'rest',
#  386: 'full',
#  387: 'crap',
#  388: 'depth',
#  389: 'horrible',
#  390: 'direction',
#  391: 'visual',
#  392: 'bit',
#  393: 'less',
#  394: 'performances',
#  395: 'trying',
#  396: 'guess',
#  397: 'lame',
#  398: 'started',
#  399: "couldn't",
#  400: 'rating',
#  401: 'three',
#  402: 'subtle',
#  403: 'young',
#  404: 'often',
#  405: 'away',
#  406: 'drago',
#  407: 'barely',
#  408: 'premise',
#  409: 'idea',
#  410: 'scamp',
#  411: 'garbage',
#  412: 'follow',
#  413: 'non',
#  414: 'keep',
#  415: 'song',
#  416: 'roles',
#  417: 'mind',
#  418: 'book',
#  419: 'mediocre',
#  420: 'itself',
#  421: 'pg',
#  422: 'strong',
#  423: 'may',
#  424: "they're",
#  425: 'minute',
#  426: 'around',
#  427: 'score',
#  428: 'since',
#  429: 'tale',
#  430: 'greatest',
#  431: "won't",
#  432: 'spoilers',
#  433: 'ed',
#  434: 'looks',
#  435: 'oscar',
#  436: 'believable',
#  437: 'actress',
#  438: 'perfect',
#  439: 'role',
#  440: 'actresses',
#  441: 'called',
#  442: 'beyond',
#  443: 'speak',
#  444: 'house',
#  445: 'shows',
#  446: 'learn',
#  447: 'embarrassing',
#  448: 'documentary',
#  449: 'appearance',
#  450: 'dvd',
#  451: "isn't",
#  452: 'james',
#  453: 'earlier',
#  454: 'level',
#  455: 'wish',
#  456: 'silent',
#  457: 'screenwriter',
#  458: 'torture',
#  459: 'convincing',
#  460: 'comes',
#  461: 'tell',
#  462: 'indulgent',
#  463: 'songs',
#  464: 'scared',
#  465: 'intelligence',
#  466: 'enjoyable',
#  467: 'checking',
#  468: 'looked',
#  469: 'themselves',
#  470: 'dance',
#  471: 'happen',
#  472: 'reason',
#  473: 'ranks',
#  474: 'acted',
#  475: 'overall',
#  476: 'plus',
#  477: 'footage',
#  478: 'sort',
#  479: 'conclusion',
#  480: 'ready',
#  481: 'unconvincing',
#  482: 'trash',
#  483: 'must',
#  484: 'coming',
#  485: 'heart',
#  486: 'while',
#  487: 'mickey',
#  488: 'including',
#  489: 'someone',
#  490: 'world',
#  491: 'war',
#  492: 'remember',
#  493: 'charles',
#  494: 'thriller',
#  495: 'usual',
#  496: 'living',
#  497: 'attention',
#  498: 'bore',
#  499: 'else',
#  500: 'dancing',
#  501: 'might',
#  502: 'significant',
#  503: 'aerial',
#  504: 'imagination',
#  505: 'came',
#  506: 'fans',
#  507: 'note',
#  508: 'surprisingly',
#  509: 'felt',
#  510: 'journey',
#  511: 'eyes',
#  512: 'child',
#  513: 'location',
#  514: 'thoroughly',
#  515: 'turn',
#  516: 'day',
#  517: 'memories',
#  518: 'billy',
#  519: 'possibly',
#  520: 'trilogy',
#  521: 'talented',
#  522: 'directed',
#  523: 'type',
#  524: 'low',
#  525: 'grace',
#  526: 'produced',
#  527: 'intelligent',
#  528: 'dialog',
#  529: 'decent',
#  530: 'stories',
#  531: 'unbelievable',
#  532: 'free',
#  533: 'occasionally',
#  534: 'angel',
#  535: 'parts',
#  536: 'gem',
#  537: 'yes',
#  538: 'seemed',
#  539: 'same',
#  540: 'brilliance',
#  541: 'close',
#  542: 'ups',
#  543: 'seem',
#  544: 'involved',
#  545: 'negative',
#  546: 'lovely',
#  547: 'generally',
#  548: 'meaning',
#  549: 'chemistry',
#  550: 'head',
#  551: 'serious',
#  552: 'brilliant',
#  553: 'created',
#  554: 'maybe',
#  555: 'picture',
#  556: 'values',
#  557: 'beginning',
#  558: 'star',
#  559: 'moving',
#  560: 'whatsoever',
#  561: "i'll",
#  562: 'plays',
#  563: 'moment',
#  564: 'emotions',
#  565: 'scenery',
#  566: 'original',
#  567: 'race',
#  568: 'paul',
#  569: 'along',
#  570: 'hours',
#  571: "wouldn't",
#  572: 'next',
#  573: 'finally',
#  574: 'stereotypes',
#  575: 'shots',
#  576: 'age',
#  577: 'spent',
#  578: 'children',
#  579: 'fan',
#  580: 'entertaining',
#  581: "you'll",
#  582: 'stage',
#  583: 'glad',
#  584: 'super',
#  585: 'hour',
#  586: 'back',
#  587: 'portrayal',
#  588: '\x96',
#  589: 'whether',
#  590: 'graphics',
#  591: 'massive',
#  592: 'yeah',
#  593: '8',
#  594: 'consider',
#  595: 'sisters',
#  596: 'fear',
#  597: 'leave',
#  598: 'begin',
#  599: 'smart',
#  600: 'ass',
#  601: 'macbeth',
#  602: 'blood',
#  603: 'notable',
#  604: 'beautifully',
#  605: 'costumes',
#  606: 'received',
#  607: 'deserved',
#  608: 'awesome',
#  609: 'bought',
#  610: 'high',
#  611: 'photography',
#  612: 'clichés',
#  613: 'lazy',
#  614: 'fast',
#  615: 'idiot',
#  616: 'several',
#  617: 'final',
#  618: 'brief',
#  619: 'moral',
#  620: 'decay',
#  621: 'forces',
#  622: 'element',
#  623: 'popular',
#  624: 'reactions',
#  625: 'plenty',
#  626: 'empty',
#  627: 'hollow',
#  628: 'frankly',
#  629: 'lane',
#  630: 'disappointment',
#  631: 'proceedings',
#  632: 'features',
#  633: 'released',
#  634: 'video',
#  635: 'adaptation',
#  636: 'below',
#  637: 'turns',
#  638: 'obviously',
#  639: 'front',
#  640: 'exquisite',
#  641: 'missed',
#  642: 'step',
#  643: 'utterly',
#  644: 'today',
#  645: 'particular',
#  646: 'delivering',
#  647: 'takes',
#  648: 'fall',
#  649: 'overly',
#  650: 'supposed',
#  651: 'our',
#  652: 'offensive',
#  653: 'cartoon',
#  654: 'already',
#  655: 'form',
#  656: 'american',
#  657: 'unfunny',
#  658: 'under',
#  659: 'stars',
#  660: 'change',
#  661: 'crowd',
#  662: 'pleaser',
#  663: 'among',
#  664: 'levels',
#  665: 'italian',
#  666: 'reviewer',
#  667: 'scale',
#  668: 'course',
#  669: 'fun',
#  670: 'goes',
#  671: 'edge',
#  672: 'somewhat',
#  673: 'afraid',
#  674: 'night',
#  675: 'predictably',
#  676: 'early',
#  677: 'implausible',
#  678: 'air',
#  679: 'store',
#  680: 'began',
#  681: 'needed',
#  682: 'seriously',
#  683: 'wilkinson',
#  684: 'uplifting',
#  685: 'seems',
#  686: 'robert',
#  687: 'father',
#  688: 'although',
#  689: 'material',
#  690: 'hence',
#  691: 'machine',
#  692: 'addition',
#  693: 'mishima',
#  694: 'uninteresting',
#  695: 'chilly',
#  696: 'working',
#  697: 'singing',
#  698: 'etc',
#  699: 'pieces',
#  700: 'schrader',
#  701: 'lousy',
#  702: 'recently',
#  703: 'struck',
#  704: 'contained',
#  705: 'holes',
#  706: 'realistic',
#  707: 'lacked',
#  708: 'talent',
#  709: 'chance',
#  710: 'theme',
#  711: 'thrilled',
#  712: 'senses',
#  713: 'deeply',
#  714: 'narrative',
#  715: 'june',
#  716: 'unfortunately',
#  717: 'plain',
#  718: 'considering',
#  719: 'superbly',
#  720: 'crafted',
#  721: 'stunning',
#  722: 'fx',
#  723: 'offers',
#  724: 'parents',
#  725: 'either',
#  726: 'mexican',
#  727: 'matter',
#  728: 'noir',
#  729: 'given',
#  730: 'complex',
#  731: 'psychological',
#  732: 'soul',
#  733: 'water',
#  734: 'gripping',
#  735: 'control',
#  736: 'sure',
#  737: 'places',
#  738: 'camerawork',
#  739: "weren't",
#  740: 'witty',
#  741: 'above',
#  742: 'favourite',
#  743: 'directors',
#  744: 'french',
#  745: 'appealing',
#  746: 'spoiler',
#  747: 'suffering',
#  748: 'smile',
#  749: 'literally',
#  750: 'told',
#  751: '25',
#  752: 'unfolds',
#  753: 'leaves',
#  754: 'room',
#  755: 'contrast',
#  756: 'sublime',
#  757: '5',
#  758: 'poetry',
#  759: 'delivers',
#  760: 'bunch',
#  761: 'overacting',
#  762: 'space',
#  763: 'warmth',
#  764: 'reality',
#  765: 'volcano',
#  766: 'los',
#  767: 'angeles',
#  768: 'nonsense',
#  769: 'ability',
#  770: 'pull',
#  771: 'issues',
#  772: 'excellently',
#  773: 'sci',
#  774: 'perhaps',
#  775: 'turned',
#  776: 'b',
#  777: 'list',
#  778: 's',
#  779: 'girlfriend',
#  780: 'hated',
#  781: 'cost',
#  782: 'mad',
#  783: '50',
#  784: 'player',
#  785: 'loneliness',
#  786: 'underneath',
#  787: 'mouse',
#  788: 'games',
#  789: 'delight',
#  790: 'sum',
#  791: 'fantastic',
#  792: 'dogs',
#  793: 'disliked',
#  794: 'problems',
#  795: 'explanation',
#  796: 'natural',
#  797: 'describe',
#  798: 'fresh',
#  799: 'paced',
#  800: 'entirely',
#  801: 'bring',
#  802: 'occupied',
#  803: 'artist',
#  804: 'voice',
#  805: 'ratings',
#  806: 'jobs',
#  807: 'main',
#  808: 'ten',
#  809: 'charm',
#  810: 'chick',
#  811: 'case',
#  812: 'tension',
#  813: 'conflict',
#  814: 'undoubtedly',
#  815: 'running',
#  816: 'creates',
#  817: 'remake',
#  818: 'friends',
#  819: 'angles',
#  820: 'following',
#  821: 'crazy',
#  822: 'portraying',
#  823: 'alexander',
#  824: 'helps',
#  825: 'wooden',
#  826: 'light',
#  827: 'forget',
#  828: 'attempts',
#  829: 'bear',
#  830: 'thinking',
#  831: 'god',
#  832: 'male',
#  833: 'thoughts',
#  834: 'terms',
#  835: 'bold',
#  836: 'writer',
#  837: 'appalling',
#  838: 'family',
#  839: 'sets',
#  840: 'composition',
#  841: 'brian',
#  842: "he's",
#  843: 'kinda',
#  844: 'cute',
#  845: 'question',
#  846: 'ask',
#  847: 'terribly',
#  848: 'jamie',
#  849: 'twist',
#  850: 'shed',
#  851: 'situation',
#  852: 'aspect',
#  853: 'reading',
#  854: 'understated',
#  855: 'revealing',
#  856: "haven't",
#  857: 'continuity',
#  858: 'thrown',
#  859: 'directorial',
#  860: 'mother',
#  861: 'impressed',
#  862: 'death',
#  863: 'computer',
#  864: 'home',
#  865: 'true',
#  866: "90's",
#  867: 'cartoons',
#  868: 'humorous',
#  869: 'cause',
#  870: 'ago',
#  871: 'explain',
#  872: 'neil',
#  873: 'balance',
#  874: 'racism',
#  875: '20th',
#  876: 'knew',
#  877: 'relations',
#  878: 'last',
#  879: 'regret',
#  880: 'quinn',
#  881: 'noteworthy',
#  882: 'touching',
#  883: 'lives',
#  884: 'set',
#  885: 'episode',
#  886: '13',
#  887: 'example',
#  888: 'jimmy',
#  889: 'century',
#  890: 'surprising',
#  891: 'sand',
#  892: 'deserving',
#  893: 'heaven',
#  894: 'uses',
#  895: 'european',
#  896: 'poorly',
#  897: 'complete',
#  898: 'interested',
#  899: 'start',
#  900: 'genuine',
#  901: 'handled',
#  902: 'despite',
#  903: 'always',
#  904: 'balanced',
#  905: 'perfectly',
#  906: 'weird',
#  907: 'racial',
#  908: 'badly',
#  909: 'wind',
#  910: 'lion',
#  911: 'eye',
#  912: 'nobody',
#  913: 'cardboard',
#  914: 'frightening',
#  915: 'themes',
#  916: 'versus',
#  917: 'courtroom',
#  918: 'length',
#  919: 'disappointing',
#  920: 'freedom',
#  921: 'words',
#  922: 'central',
#  923: 'presents',
#  924: 'imaginable',
#  925: 'depicts',
#  926: 'wonder',
#  927: 'putting',
#  928: 'exceptional',
#  929: 'accused',
#  930: 'south',
#  931: 'assistant',
#  932: 'bored',
#  933: 'happened',
#  934: 'wonderfully',
#  935: 'easy',
#  936: 'lange',
#  937: 'duet',
#  938: 'appreciate',
#  939: 'quality',
#  940: 'wayne',
#  941: 'industry',
#  942: 'presence',
#  943: 'genius',
#  944: 'owned',
#  945: 'daughter',
#  946: 'provoking',
#  947: 'ruthless',
#  948: 'fat',
#  949: 'lighting',
#  950: "joe's",
#  951: 'charming',
#  952: 'junkyard',
#  953: 'buy',
#  954: 'female',
#  955: 'hill',
#  956: 'doctor',
#  957: 'business',
#  958: 'faux',
#  959: 'drive',
#  960: 'pure',
#  961: 'easily',
#  962: 'important',
#  963: 'fit',
#  964: 'create',
#  965: 'deserves',
#  966: 'canada',
#  967: 'sequel',
#  968: 'rated',
#  969: 'joke',
#  970: 'obvious',
#  971: 'choice',
#  972: 'lesser',
#  973: '2',
#  974: 'whiny',
#  975: 'anne',
#  976: 'honestly',
#  977: 'unpredictable',
#  978: "aren't",
#  979: 'fifteen',
#  980: 'pleased',
#  981: 'feel',
#  982: 'instead',
#  983: 'taking',
#  984: 'review',
#  985: 'overdue',
#  986: 'inspiration',
#  987: 'overcome',
#  988: 'rejection',
#  989: 'shelf',
#  990: 'captures',
#  991: 'essence',
#  992: 'comments',
#  993: 'wall',
#  994: 'uncalled',
#  995: 'helen',
#  996: 'baxendale',
#  997: 'credible',
#  998: 'lady',
#  999: 'cheerfull',
#  1000: 'naughty',
#  ...}

# %%
sequences_train = tok.texts_to_sequences(x_train)

# %%
# sequences_train

# %%
vocab_len=len(tok.index_word.keys())

# %%
vocab_len
# Out:
# 2688

# %%
sequences_matrix_train = sequence.pad_sequences(sequences_train,maxlen=max_len)

# %%
sequences_matrix_train
# Out:
# array([[  0,   0,   0, ...,  30,  90, 426],
#        [  0,   0,   0, ...,  10, 275,  94],
#        [  0,   0,   0, ...,  18,   1,  71],
#        ...,
#        [  0,   0,   0, ...,  44,  64,  84],
#        [  0,   0,   0, ..., 284, 284, 284],
#        [  0,   0,   0, ..., 383,  20, 307]], dtype=int32)

# %%
def RNN():
    inputs = Input(name='inputs',shape=[max_len])
    
    layer = Embedding(vocab_len+1,vocab_len+1,input_length=max_len,
                      mask_zero=True)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %%
model = RNN()
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 63)]              0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 63, 2689)          7230721
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                705024
# _________________________________________________________________
# FC1 (Dense)                  (None, 256)               16640
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 257
# _________________________________________________________________
# activation_5 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 7,952,642
# Trainable params: 7,952,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',
              metrics=['accuracy'])

# %%
sequences_test = tok.texts_to_sequences(x_test)
sequences_matrix_test = sequence.pad_sequences(sequences_test,
                                               maxlen=max_len)

# %%
model.fit(sequences_matrix_train,y_train.values,batch_size=50,
          epochs=3,validation_data=(sequences_matrix_test,y_test.values))
# Out:
# Train on 598 samples, validate on 150 samples
# Epoch 1/3
# 598/598 [==============================] - 10s 17ms/sample - loss: 2.5351e-04 - acc: 1.0000 - val_loss: 1.3322 - val_acc: 0.8000
# Epoch 2/3
# 598/598 [==============================] - 10s 17ms/sample - loss: 2.3643e-04 - acc: 1.0000 - val_loss: 1.3480 - val_acc: 0.8000
# Epoch 3/3
# 598/598 [==============================] - 10s 17ms/sample - loss: 1.8075e-04 - acc: 1.0000 - val_loss: 1.3627 - val_acc: 0.8000

# %%
predictions=model.predict(sequences_matrix_test)

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test,predictions)
# Out:
# 0.8721595992127392

# %%
# if you notice the validation loss , it is actually increasing after some epochs , best model appears much earlier than 
# 50th epoch
